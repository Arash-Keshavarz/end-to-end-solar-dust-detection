# %% [markdown]
# ## Download Data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1ugZsVw03YafQMvPi7J6E7rD6Tq6jhizz/view?usp=sharing"

# %%
file_id =url.split("/")[-2]
prefix_url = "https://drive.google.com/uc?export=download&id="

gdown.download(prefix_url + file_id, "solar_dust_detection.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1ugZsVw03YafQMvPi7J6E7rD6Tq6jhizz
# From (redirected): https://drive.google.com/uc?export=download&id=1ugZsVw03YafQMvPi7J6E7rD6Tq6jhizz&confirm=t&uuid=1e577a35-45bf-423f-8724-1d95a7e5a728
# To: /Users/arash/ML_End_to_End_Pj/end-to-end-solar-dust-detection/research/solar_dust_detection.zip
# 100%|██████████| 1.27G/1.27G [01:33<00:00, 13.6MB/s]
# 'solar_dust_detection.zip'

# %%
image_size = [224, 224, 3]

image_size[:-1]
# Out:
# [224, 224]
